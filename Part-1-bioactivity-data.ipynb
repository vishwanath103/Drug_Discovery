# %% [markdown]
# ## Installing libraries

# %%
# !pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in c:\users\bailo\anaconda3\envs\myenv\lib\site-packages (0.10.4)
# Requirement already satisfied: urllib3 in c:\users\bailo\anaconda3\envs\myenv\lib\site-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: requests>=2.18.4 in c:\users\bailo\anaconda3\envs\myenv\lib\site-packages (from chembl_webresource_client) (2.24.0)
# Requirement already satisfied: easydict in c:\users\bailo\anaconda3\envs\myenv\lib\site-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: requests-cache>=0.6.0 in c:\users\bailo\anaconda3\envs\myenv\lib\site-packages (from chembl_webresource_client) (0.6.4)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\bailo\anaconda3\envs\myenv\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bailo\anaconda3\envs\myenv\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\bailo\anaconda3\envs\myenv\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: itsdangerous in c:\users\bailo\anaconda3\envs\myenv\lib\site-packages (from requests-cache>=0.6.0->chembl_webresource_client) (2.0.1)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\bailo\anaconda3\envs\myenv\lib\site-packages (from requests-cache>=0.6.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in c:\users\bailo\anaconda3\envs\myenv\lib\site-packages (from url-normalize>=1.4->requests-cache>=0.6.0->chembl_webresource_client) (1.15.0)

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## Search for Target protein

# %%
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets.head()
# Out:
#                                     cross_references                 organism  \
# 0  [{'xref_id': 'P22303', 'xref_name': None, 'xre...             Homo sapiens
# 1                                                 []             Homo sapiens
# 2                                                 []  Drosophila melanogaster
# 3  [{'xref_id': 'P04058', 'xref_name': None, 'xre...      Torpedo californica
# 4  [{'xref_id': 'P21836', 'xref_name': None, 'xre...             Mus musculus
#
#                       pref_name  score  species_group_flag target_chembl_id  \
# 0          Acetylcholinesterase   27.0               False        CHEMBL220
# 1  Cholinesterases; ACHE & BCHE   27.0               False    CHEMBL2095233
# 2          Acetylcholinesterase   17.0               False    CHEMBL2242744
# 3          Acetylcholinesterase   15.0               False       CHEMBL4780
# 4          Acetylcholinesterase   15.0               False       CHEMBL3198
#
#                                    target_components        target_type  \
# 0  [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 1  [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
# 2  [{'accession': 'P07140', 'component_descriptio...     SINGLE PROTEIN
# 3  [{'accession': 'P04058', 'component_descriptio...     SINGLE PROTEIN
# 4  [{'accession': 'P21836', 'component_descriptio...     SINGLE PROTEIN
#
#    tax_id
# 0    9606
# 1    9606
# 2    7227
# 3    7787
# 4   10090

# %% [markdown]
# ## Select and retrieve bioactivity data for first entry

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL220'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type='IC50')

# %%
df = pd.DataFrame.from_dict(res)
df.head()
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None        33969                  []    CHEMBL643384
# 1             None        37563                  []    CHEMBL643384
# 2             None        37565                  []    CHEMBL643384
# 3             None        38902                  []    CHEMBL643384
# 4             None        41170                  []    CHEMBL643384
#
#                                    assay_description assay_type  \
# 0  Inhibitory concentration against acetylcholine...          B
# 1  Inhibitory concentration against acetylcholine...          B
# 2  Inhibitory concentration against acetylcholine...          B
# 3  Inhibitory concentration against acetylcholine...          B
# 4  Inhibitory concentration against acetylcholine...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000357
# 1                    None                   None  BAO_0000190  BAO_0000357
# 2                    None                   None  BAO_0000190  BAO_0000357
# 3                    None                   None  BAO_0000190  BAO_0000357
# 4                    None                   None  BAO_0000190  BAO_0000357
#
#    ... target_organism      target_pref_name target_tax_id text_value  toid  \
# 0  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 1  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 2  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 3  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 4  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
#
#    type  units    uo_units upper_value value
# 0  IC50     uM  UO_0000065        None  0.75
# 1  IC50     uM  UO_0000065        None   0.1
# 2  IC50     uM  UO_0000065        None  50.0
# 3  IC50     uM  UO_0000065        None   0.3
# 4  IC50     uM  UO_0000065        None   0.8
#
# [5 rows x 45 columns]

# %%
df.columns
# Out:
# Index(['activity_comment', 'activity_id', 'activity_properties',
#        'assay_chembl_id', 'assay_description', 'assay_type',
#        'assay_variant_accession', 'assay_variant_mutation', 'bao_endpoint',
#        'bao_format', 'bao_label', 'canonical_smiles', 'data_validity_comment',
#        'data_validity_description', 'document_chembl_id', 'document_journal',
#        'document_year', 'ligand_efficiency', 'molecule_chembl_id',
#        'molecule_pref_name', 'parent_molecule_chembl_id', 'pchembl_value',
#        'potential_duplicate', 'qudt_units', 'record_id', 'relation', 'src_id',
#        'standard_flag', 'standard_relation', 'standard_text_value',
#        'standard_type', 'standard_units', 'standard_upper_value',
#        'standard_value', 'target_chembl_id', 'target_organism',
#        'target_pref_name', 'target_tax_id', 'text_value', 'toid', 'type',
#        'units', 'uo_units', 'upper_value', 'value'],
#       dtype='object')

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## Handling missing data

# %%
df2 = df[df.standard_value.notna()]
df2 = df[df.canonical_smiles.notna()]
df2.head()
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None        33969                  []    CHEMBL643384
# 1             None        37563                  []    CHEMBL643384
# 2             None        37565                  []    CHEMBL643384
# 3             None        38902                  []    CHEMBL643384
# 4             None        41170                  []    CHEMBL643384
#
#                                    assay_description assay_type  \
# 0  Inhibitory concentration against acetylcholine...          B
# 1  Inhibitory concentration against acetylcholine...          B
# 2  Inhibitory concentration against acetylcholine...          B
# 3  Inhibitory concentration against acetylcholine...          B
# 4  Inhibitory concentration against acetylcholine...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000357
# 1                    None                   None  BAO_0000190  BAO_0000357
# 2                    None                   None  BAO_0000190  BAO_0000357
# 3                    None                   None  BAO_0000190  BAO_0000357
# 4                    None                   None  BAO_0000190  BAO_0000357
#
#    ... target_organism      target_pref_name target_tax_id text_value  toid  \
# 0  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 1  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 2  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 3  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
# 4  ...    Homo sapiens  Acetylcholinesterase          9606       None  None
#
#    type  units    uo_units upper_value value
# 0  IC50     uM  UO_0000065        None  0.75
# 1  IC50     uM  UO_0000065        None   0.1
# 2  IC50     uM  UO_0000065        None  50.0
# 3  IC50     uM  UO_0000065        None   0.3
# 4  IC50     uM  UO_0000065        None   0.8
#
# [5 rows x 45 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 6149

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                None        33969                  []    CHEMBL643384
# 1                None        37563                  []    CHEMBL643384
# 2                None        37565                  []    CHEMBL643384
# 3                None        38902                  []    CHEMBL643384
# 4                None        41170                  []    CHEMBL643384
# ...               ...          ...                 ...             ...
# 7473             None     19468458                  []   CHEMBL4478126
# 7474             None     19468459                  []   CHEMBL4478126
# 7475             None     19468460                  []   CHEMBL4478126
# 7477             None     19487204                  []   CHEMBL4481753
# 7478             None     19487205                  []   CHEMBL4481753
#
#                                       assay_description assay_type  \
# 0     Inhibitory concentration against acetylcholine...          B
# 1     Inhibitory concentration against acetylcholine...          B
# 2     Inhibitory concentration against acetylcholine...          B
# 3     Inhibitory concentration against acetylcholine...          B
# 4     Inhibitory concentration against acetylcholine...          B
# ...                                                 ...        ...
# 7473  Inhibition of human erythrocyte AChE using ATC...          B
# 7474  Inhibition of human erythrocyte AChE using ATC...          B
# 7475  Inhibition of human erythrocyte AChE using ATC...          B
# 7477  Inhibition of AChE (unknown origin) using acet...          B
# 7478  Inhibition of AChE (unknown origin) using acet...          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                       None                   None  BAO_0000190  BAO_0000357
# 1                       None                   None  BAO_0000190  BAO_0000357
# 2                       None                   None  BAO_0000190  BAO_0000357
# 3                       None                   None  BAO_0000190  BAO_0000357
# 4                       None                   None  BAO_0000190  BAO_0000357
# ...                      ...                    ...          ...          ...
# 7473                    None                   None  BAO_0000190  BAO_0000357
# 7474                    None                   None  BAO_0000190  BAO_0000357
# 7475                    None                   None  BAO_0000190  BAO_0000357
# 7477                    None                   None  BAO_0000190  BAO_0000357
# 7478                    None                   None  BAO_0000190  BAO_0000357
#
#       ... target_organism      target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 1     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 2     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 3     ...    Homo sapiens  Acetylcholinesterase          9606       None
# 4     ...    Homo sapiens  Acetylcholinesterase          9606       None
# ...   ...             ...                   ...           ...        ...
# 7473  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7474  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7475  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7477  ...    Homo sapiens  Acetylcholinesterase          9606       None
# 7478  ...    Homo sapiens  Acetylcholinesterase          9606       None
#
#       toid  type  units    uo_units upper_value value
# 0     None  IC50     uM  UO_0000065        None  0.75
# 1     None  IC50     uM  UO_0000065        None   0.1
# 2     None  IC50     uM  UO_0000065        None  50.0
# 3     None  IC50     uM  UO_0000065        None   0.3
# 4     None  IC50     uM  UO_0000065        None   0.8
# ...    ...   ...    ...         ...         ...   ...
# 7473  None  IC50     uM  UO_0000065        None  10.0
# 7474  None  IC50     uM  UO_0000065        None  7.57
# 7475  None  IC50     uM  UO_0000065        None  10.0
# 7477  None  IC50     uM  UO_0000065        None  15.5
# 7478  None  IC50     uM  UO_0000065        None  68.3
#
# [6149 rows x 45 columns]

# %% [markdown]
# ## Data pre-processing
#
# Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1       CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2       CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3       CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4       CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
#
#   standard_value
# 0          750.0
# 1          100.0
# 2        50000.0
# 3          300.0
# 4          800.0

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# Labelling compounds as either being active, inactive or intermediate

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
    if float(i) >= 10000:
        bioactivity_threshold.append("inactive")
    elif float(i) <= 1000:
        bioactivity_threshold.append("active")
    else:
        bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1       CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2       CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3       CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4       CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
#
#    standard_value     class
# 0           750.0    active
# 1           100.0    active
# 2         50000.0  inactive
# 3           300.0    active
# 4           800.0    active

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)
